# %%
import pandas as pd

# %%
red_wine = pd.read_csv('./data/winequality-red.csv', sep=';')
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_wine = pd.read_csv('./data/winequality-white.csv',sep=';')
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
red_wine.insert(11, 'class', 0)
white_wine.insert(11, 'class', 1)

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  class  quality
# 0      9.4      0        5
# 1      9.8      0        5
# 2      9.8      0        5
# 3      9.8      0        6
# 4      9.4      0        5

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  class  quality
# 0      8.8      1        6
# 1      9.5      1        6
# 2     10.1      1        6
# 3      9.9      1        6
# 4      9.9      1        6

# %%
wine_df = pd.concat([red_wine, white_wine], ignore_index=True)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  class  quality
# 0         9.4      0        5
# 1         9.8      0        5
# 2         9.8      0        5
# 3         9.8      0        6
# 4         9.4      0        5
# ...       ...    ...      ...
# 6492     11.2      1        6
# 6493      9.6      1        5
# 6494      9.4      1        6
# 6495     12.8      1        7
# 6496     11.8      1        6
#
# [6497 rows x 13 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

mm_scaler = MinMaxScaler()
wine_df[['fixed acidity', 'residual sugar', 'free sulfur dioxide', 'total sulfur dioxide', 'pH', 'alcohol']] = \
mm_scaler.fit_transform(wine_df[['fixed acidity', 'residual sugar', 'free sulfur dioxide', 'total sulfur dioxide', 'pH', 'alcohol']])
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.297521              0.70         0.00        0.019939      0.076
# 1          0.330579              0.88         0.00        0.030675      0.098
# 2          0.330579              0.76         0.04        0.026074      0.092
# 3          0.611570              0.28         0.56        0.019939      0.075
# 4          0.297521              0.70         0.00        0.019939      0.076
# ...             ...               ...          ...             ...        ...
# 6492       0.198347              0.21         0.29        0.015337      0.039
# 6493       0.231405              0.32         0.36        0.113497      0.047
# 6494       0.223140              0.24         0.19        0.009202      0.041
# 6495       0.140496              0.29         0.30        0.007669      0.022
# 6496       0.181818              0.21         0.38        0.003067      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density        pH  sulphates  \
# 0                0.034722              0.064516  0.99780  0.612403       0.56
# 1                0.083333              0.140553  0.99680  0.372093       0.68
# 2                0.048611              0.110599  0.99700  0.418605       0.65
# 3                0.055556              0.124424  0.99800  0.341085       0.58
# 4                0.034722              0.064516  0.99780  0.612403       0.56
# ...                   ...                   ...      ...       ...        ...
# 6492             0.079861              0.198157  0.99114  0.426357       0.50
# 6493             0.194444              0.373272  0.99490  0.333333       0.46
# 6494             0.100694              0.241935  0.99254  0.209302       0.46
# 6495             0.065972              0.239631  0.98869  0.480620       0.38
# 6496             0.072917              0.211982  0.98941  0.418605       0.32
#
#        alcohol  class  quality
# 0     0.202899      0        5
# 1     0.260870      0        5
# 2     0.260870      0        5
# 3     0.260870      0        6
# 4     0.202899      0        5
# ...        ...    ...      ...
# 6492  0.463768      1        6
# 6493  0.231884      1        5
# 6494  0.202899      1        6
# 6495  0.695652      1        7
# 6496  0.550725      1        6
#
# [6497 rows x 13 columns]

# %%
X = wine_df.iloc[:, :12]
y = wine_df.iloc[:, 12]

# %%
from tensorflow.keras import models, layers
from tensorflow import keras
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)
model = models.Sequential()
model.add(keras.Input(shape=(X_train.shape[1],)))
model.add(layers.Dense(24, activation='relu'))
model.add(layers.Dense(48, activation='relu'))
model.add(layers.Dense(12, activation='relu'))
model.add(layers.Dense(1))
model.summary()
# Out:
# c:\PYTHONWORKSPACE\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 24)             │           312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 48)             │         1,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 12)             │           588 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,113 (8.25 KB)
#  Trainable params: 2,113 (8.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(X_train, y_train, epochs=50, batch_size=10)
# Out:
# Epoch 1/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 5.6055
# Epoch 2/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6308
# Epoch 3/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5800
# Epoch 4/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5656
# Epoch 5/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5595
# Epoch 6/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5619
# Epoch 7/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5488
# Epoch 8/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5546
# Epoch 9/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5460
# Epoch 10/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5452
# Epoch 11/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5418
# Epoch 12/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5449
# Epoch 13/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5431
# Epoch 14/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5483
# Epoch 15/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5425
# Epoch 16/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5357
# Epoch 17/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5307
# Epoch 18/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5290
# Epoch 19/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5255
# Epoch 20/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5287
# Epoch 21/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5262
# Epoch 22/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5350
# Epoch 23/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5243
# Epoch 24/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5235
# Epoch 25/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5169
# Epoch 26/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5173
# Epoch 27/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5221
# Epoch 28/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5182
# Epoch 29/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5192
# Epoch 30/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5146
# Epoch 31/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5129
# Epoch 32/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5117
# Epoch 33/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5216
# Epoch 34/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5128
# Epoch 35/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5130
# Epoch 36/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5076
# Epoch 37/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5119
# Epoch 38/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5145
# Epoch 39/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5102
# Epoch 40/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5128
# Epoch 41/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5077
# Epoch 42/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5124
# Epoch 43/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5138
# Epoch 44/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5101
# Epoch 45/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5074
# Epoch 46/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5074
# Epoch 47/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5096
# Epoch 48/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5115
# Epoch 49/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5042
# Epoch 50/50
# 488/488 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5072

# %%
target_qualities = []
prediction_qualities = []
x_tick = []

counter = 0
y_prediction = model.predict(X_test).flatten()
for i in range(50):
    target = y_test.iloc[i]
    prediction = y_prediction[i]
    print("실제 품질: {:.2f}, 예측 품질: {:.2f}".format(target, prediction))
    target_qualities.append(target)
    prediction_qualities.append(prediction)
    counter += 1
    x_tick.append(counter)
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 실제 품질: 6.00, 예측 품질: 5.63
# 실제 품질: 7.00, 예측 품질: 6.20
# 실제 품질: 5.00, 예측 품질: 6.24
# 실제 품질: 5.00, 예측 품질: 5.51
# 실제 품질: 5.00, 예측 품질: 5.63
# 실제 품질: 6.00, 예측 품질: 5.98
# 실제 품질: 6.00, 예측 품질: 6.96
# 실제 품질: 4.00, 예측 품질: 5.10
# 실제 품질: 5.00, 예측 품질: 5.25
# 실제 품질: 5.00, 예측 품질: 4.09
# 실제 품질: 6.00, 예측 품질: 5.67
# 실제 품질: 6.00, 예측 품질: 6.37
# 실제 품질: 5.00, 예측 품질: 5.76
# 실제 품질: 6.00, 예측 품질: 5.39
# 실제 품질: 6.00, 예측 품질: 5.98
# 실제 품질: 7.00, 예측 품질: 6.23
# 실제 품질: 5.00, 예측 품질: 6.13
# 실제 품질: 4.00, 예측 품질: 4.89
# 실제 품질: 5.00, 예측 품질: 5.81
# 실제 품질: 7.00, 예측 품질: 6.82
# 실제 품질: 5.00, 예측 품질: 5.98
# 실제 품질: 5.00, 예측 품질: 5.69
# 실제 품질: 5.00, 예측 품질: 6.11
# 실제 품질: 6.00, 예측 품질: 6.66
# 실제 품질: 6.00, 예측 품질: 6.55
# 실제 품질: 6.00, 예측 품질: 5.65
# 실제 품질: 5.00, 예측 품질: 5.25
# 실제 품질: 6.00, 예측 품질: 6.40
# 실제 품질: 4.00, 예측 품질: 5.89
# 실제 품질: 5.00, 예측 품질: 5.23
# 실제 품질: 5.00, 예측 품질: 5.31
# 실제 품질: 6.00, 예측 품질: 5.43
# 실제 품질: 5.00, 예측 품질: 5.39
# 실제 품질: 5.00, 예측 품질: 5.87
# 실제 품질: 5.00, 예측 품질: 5.91
# 실제 품질: 7.00, 예측 품질: 6.51
# 실제 품질: 6.00, 예측 품질: 6.70
# 실제 품질: 5.00, 예측 품질: 6.40
# 실제 품질: 8.00, 예측 품질: 6.79
# 실제 품질: 5.00, 예측 품질: 5.62
# 실제 품질: 5.00, 예측 품질: 5.43
# 실제 품질: 5.00, 예측 품질: 5.54
# 실제 품질: 5.00, 예측 품질: 6.21
# 실제 품질: 6.00, 예측 품질: 6.01
# 실제 품질: 5.00, 예측 품질: 5.65
# 실제 품질: 6.00, 예측 품질: 5.94
# 실제 품질: 6.00, 예측 품질: 6.12
# 실제 품질: 8.00, 예측 품질: 6.68
# 실제 품질: 5.00, 예측 품질: 5.18
# 실제 품질: 6.00, 예측 품질: 5.87
